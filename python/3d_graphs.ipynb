# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d as plt_3d
from matplotlib.animation import PillowWriter

# %%
ax = plt.axes(projection="3d") #plotting a 3d axes
# ordered linespace
X=np.arange(-5,5,0.1)
Y=np.arange(-5,5,0.1)
Z=np.arange(-5,5,0.1)
# random points unordered 
X_rand=np.random.randint(-50,50,2*10**3)*0.05
Y_rand=np.random.randint(-50,50,2*10**3)*0.05
Z_rand=np.random.randint(-50,50,2*10**3)*0.05

plt.scatter(X_rand,Y_rand,Z_rand)

# %%
def f(x,y) :
    return np.exp(-(x**2 +y**2))
def g(x,y) :
    return np.sin(x)*np.cos(y)

# %%
_X,_Y = np.meshgrid(X,Y)
_Z = _X*_Y
_G = g(_X,_Y)

# %%
ax.plot_surface(_X,_Y,_G,alpha=1,cmap="plasma")
plt.show()

# %% [markdown]
# $\sum{a**2}$
